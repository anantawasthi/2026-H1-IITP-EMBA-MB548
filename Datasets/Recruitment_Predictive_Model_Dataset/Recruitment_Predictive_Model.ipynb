# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import os
# Put your system path here
os.chdir('')

# %%
data = pd.read_excel('Recruitment_Predictive_Model_Dataset.xlsx')

# %%
data.shape
# Out:
# (1000, 12)

# %%
data.head()
# Out:
#   Candidate_ID  Age  Years_of_Experience Education_Level  Skill_Match_Score  \
# 0       CN0175   24                  0.5        Bachelor               72.2
# 1       CN0143   31                  8.0        Bachelor               58.2
# 2       CN0422   27                  3.6             PhD               78.7
# 3       CN0470   29                  7.2          Master               66.0
# 4       CN0174   42                 12.6        Bachelor               55.6
#
#    Interview_Score  Aptitude_Test_Score  Communication_Rating  \
# 0             48.1                 67.7                     4
# 1             52.1                 71.8                     4
# 2             68.9                 74.3                     1
# 3             79.6                 73.9                     1
# 4             59.7                 56.9                     3
#
#    Relevant_Certifications  Notice_Period_Days  Expected_Salary_LPA  \
# ...

# %%
data.columns
# Out:
# Index(['Candidate_ID', 'Age', 'Years_of_Experience', 'Education_Level',
#        'Skill_Match_Score', 'Interview_Score', 'Aptitude_Test_Score',
#        'Communication_Rating', 'Relevant_Certifications', 'Notice_Period_Days',
#        'Expected_Salary_LPA', 'Hiring_Decision'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Candidate_ID             1000 non-null   object
#  1   Age                      1000 non-null   int64
#  2   Years_of_Experience      1000 non-null   float64
#  3   Education_Level          1000 non-null   object
#  4   Skill_Match_Score        1000 non-null   float64
#  5   Interview_Score          1000 non-null   float64
#  6   Aptitude_Test_Score      1000 non-null   float64
#  7   Communication_Rating     1000 non-null   int64
#  8   Relevant_Certifications  1000 non-null   int64
#  9   Notice_Period_Days       1000 non-null   int64
#  10  Expected_Salary_LPA      1000 non-null   float64
#  11  Hiring_Decision          1000 non-null   object
# dtypes: float64(5), int64(4), object(3)
# memory usage: 93.9+ KB
